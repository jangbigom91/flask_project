# %% [markdown]
# ## 미세먼지 데이터 분석
# #### Train 데이터는 2014년 1월~2020년 12월까지의 정보 활용
# #### Test 데이터는 2021년 1월~6월까지의 정보 활용

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# csv 파일 읽어오기
train = pd.read_csv('raw_train.csv')

# %%
# dust : 2557 row, 8 column
train.shape
# Out:
# (2557, 8)

# %%
# dust 첫 5행
train.head()
# Out:
#        Date  Temperature  W_speed  W_direction  Humidity  Tianjin  Weihai  \
# 0  20140101          4.0      3.7          270      51.3      136     116
# 1  20140102          1.5      2.0          290      35.4      216      80
# 2  20140103          2.3      2.5           50      54.4      102      67
# 3  20140104         -0.1      2.4          270      47.1       74      30
# 4  20140105         -0.8      1.9          270      48.4      114      77
#
#    Seoul
# 0    125
# 1     56
# 2     59
# 3     51
# 4     45

# %%
# 각 column별 null 개수
train.isnull().sum()
# Out:
# Date           0
# Temperature    0
# W_speed        0
# W_direction    0
# Humidity       0
# Tianjin        0
# Weihai         0
# Seoul          0
# dtype: int64

# %%
# 각 column별 데이터 타입
train.dtypes
# Out:
# Date             int64
# Temperature    float64
# W_speed        float64
# W_direction      int64
# Humidity       float64
# Tianjin          int64
# Weihai           int64
# Seoul            int64
# dtype: object

# %%
# 각 column별 히스토그램 출력
train.hist(bins=50, figsize=(20, 15)) # bins : 구간 경계값
# Out:
# array([[<AxesSubplot:title={'center':'Date'}>,
#         <AxesSubplot:title={'center':'Temperature'}>,
#         <AxesSubplot:title={'center':'W_speed'}>],
#        [<AxesSubplot:title={'center':'W_direction'}>,
#         <AxesSubplot:title={'center':'Humidity'}>,
#         <AxesSubplot:title={'center':'Tianjin'}>],
#        [<AxesSubplot:title={'center':'Weihai'}>,
#         <AxesSubplot:title={'center':'Seoul'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
# 날짜별 미세먼지 평균 근황
graph1 = sns.barplot(x='Date', y='Seoul', data=train)
plt.xticks(rotation=0)
# Out:
# (array([   0,    1,    2, ..., 2554, 2555, 2556]),
#  [Text(0, 0, '20140101'),
#   Text(1, 0, '20140102'),
#   Text(2, 0, '20140103'),
#   Text(3, 0, '20140104'),
#   Text(4, 0, '20140105'),
#   Text(5, 0, '20140106'),
#   Text(6, 0, '20140107'),
#   Text(7, 0, '20140108'),
#   Text(8, 0, '20140109'),
#   Text(9, 0, '20140110'),
#   Text(10, 0, '20140111'),
#   Text(11, 0, '20140112'),
#   Text(12, 0, '20140113'),
#   Text(13, 0, '20140114'),
#   Text(14, 0, '20140115'),
#   Text(15, 0, '20140116'),
#   Text(16, 0, '20140117'),
#   Text(17, 0, '20140118'),
#   Text(18, 0, '20140119'),
#   Text(19, 0, '20140120'),
#   Text(20, 0, '20140121'),
#   Text(21, 0, '20140122'),
#   Text(22, 0, '20140123'),
#   Text(23, 0, '20140124'),
#   Text(24, 0, '20140125'),
#   Text(25, 0, '20140126'),
#   Text(26, 0, '20140127'),
#   Text(27, 0, '20140128'),
#   Text(28, 0, '20140129'),
#   Text(29, 0, '20140130'),
#   Text(30, 0, '20140131'),
#   Text(31, 0, '20140201'),
#   Text(32, 0, '20140202'),
#   Text(33, 0, '20140203'),
#   Text(34, 0, '20140204'),
#   Text(35, 0, '20140205'),
#   Text(36, 0, '20140206'),
#   Text(37, 0, '20140207'),
#   Text(38, 0, '20140208'),
#   Text(39, 0, '20140209'),
#   Text(40, 0, '20140210'),
#   Text(41, 0, '20140211'),
#   Text(42, 0, '20140212'),
#   Text(43, 0, '20140213'),
#   Text(44, 0, '20140214'),
#   Text(45, 0, '20140215'),
#   Text(46, 0, '20140216'),
#   Text(47, 0, '20140217'),
#   Text(48, 0, '20140218'),
#   Text(49, 0, '20140219'),
#   Text(50, 0, '20140220'),
#   Text(51, 0, '20140221'),
#   Text(52, 0, '20140222'),
#   Text(53, 0, '20140223'),
#   Text(54, 0, '20140224'),
#   Text(55, 0, '20140225'),
#   Text(56, 0, '20140226'),
#   Text(57, 0, '20140227'),
#   Text(58, 0, '20140228'),
#   Text(59, 0, '20140301'),
#   Text(60, 0, '20140302'),
#   Text(61, 0, '20140303'),
#   Text(62, 0, '20140304'),
#   Text(63, 0, '20140305'),
#   Text(64, 0, '20140306'),
#   Text(65, 0, '20140307'),
#   Text(66, 0, '20140308'),
#   Text(67, 0, '20140309'),
#   Text(68, 0, '20140310'),
#   Text(69, 0, '20140311'),
#   Text(70, 0, '20140312'),
#   Text(71, 0, '20140313'),
#   Text(72, 0, '20140314'),
#   Text(73, 0, '20140315'),
#   Text(74, 0, '20140316'),
#   Text(75, 0, '20140317'),
#   Text(76, 0, '20140318'),
#   Text(77, 0, '20140319'),
#   Text(78, 0, '20140320'),
#   Text(79, 0, '20140321'),
#   Text(80, 0, '20140322'),
#   Text(81, 0, '20140323'),
#   Text(82, 0, '20140324'),
#   Text(83, 0, '20140325'),
#   Text(84, 0, '20140326'),
#   Text(85, 0, '20140327'),
#   Text(86, 0, '20140328'),
#   Text(87, 0, '20140329'),
#   Text(88, 0, '20140330'),
#   Text(89, 0, '20140331'),
#   Text(90, 0, '20140401'),
#   Text(91, 0, '20140402'),
#   Text(92, 0, '20140403'),
#   Text(93, 0, '20140404'),
#   Text(94, 0, '20140405'),
#   Text(95, 0, '20140406'),
#   Text(96, 0, '20140407'),
#   Text(97, 0, '20140408'),
#   Text(98, 0, '20140409'),
#   Text(99, 0, '20140410'),
#   Text(100, 0, '20140411'),
#   Text(101, 0, '20140412'),
#   Text(102, 0, '20140413'),
#   Text(103, 0, '20140414'),
#   Text(104, 0, '20140415'),
#   Text(105, 0, '20140416'),
#   Text(106, 0, '20140417'),
#   Text(107, 0, '20140418'),
#   Text(108, 0, '20140419'),
#   Text(109, 0, '20140420'),
#   Text(110, 0, '20140421'),
#   Text(111, 0, '20140422'),
#   Text(112, 0, '20140423'),
#   Text(113, 0, '20140424'),
#   Text(114, 0, '20140425'),
#   Text(115, 0, '20140426'),
#   Text(116, 0, '20140427'),
#   Text(117, 0, '20140428'),
#   Text(118, 0, '20140429'),
#   Text(119, 0, '20140430'),
#   Text(120, 0, '20140501'),
#   Text(121, 0, '20140502'),
#   Text(122, 0, '20140503'),
#   Text(123, 0, '20140504'),
#   Text(124, 0, '20140505'),
#   Text(125, 0, '20140506'),
#   Text(126, 0, '20140507'),
#   Text(127, 0, '20140508'),
#   Text(128, 0, '20140509'),
#   Text(129, 0, '20140510'),
#   Text(130, 0, '20140511'),
#   Text(131, 0, '20140512'),
#   Text(132, 0, '20140513'),
#   Text(133, 0, '20140514'),
#   Text(134, 0, '20140515'),
#   Text(135, 0, '20140516'),
#   Text(136, 0, '20140517'),
#   Text(137, 0, '20140518'),
#   Text(138, 0, '20140519'),
#   Text(139, 0, '20140520'),
#   Text(140, 0, '20140521'),
#   Text(141, 0, '20140522'),
#   Text(142, 0, '20140523'),
#   Text(143, 0, '20140524'),
#   Text(144, 0, '20140525'),
#   Text(145, 0, '20140526'),
#   Text(146, 0, '20140527'),
#   Text(147, 0, '20140528'),
#   Text(148, 0, '20140529'),
#   Text(149, 0, '20140530'),
#   Text(150, 0, '20140531'),
#   Text(151, 0, '20140601'),
#   Text(152, 0, '20140602'),
#   Text(153, 0, '20140603'),
#   Text(154, 0, '20140604'),
#   Text(155, 0, '20140605'),
#   Text(156, 0, '20140606'),
#   Text(157, 0, '20140607'),
#   Text(158, 0, '20140608'),
#   Text(159, 0, '20140609'),
#   Text(160, 0, '20140610'),
#   Text(161, 0, '20140611'),
#   Text(162, 0, '20140612'),
#   Text(163, 0, '20140613'),
#   Text(164, 0, '20140614'),
#   Text(165, 0, '20140615'),
#   Text(166, 0, '20140616'),
#   Text(167, 0, '20140617'),
#   Text(168, 0, '20140618'),
#   Text(169, 0, '20140619'),
#   Text(170, 0, '20140620'),
#   Text(171, 0, '20140621'),
#   Text(172, 0, '20140622'),
#   Text(173, 0, '20140623'),
#   Text(174, 0, '20140624'),
#   Text(175, 0, '20140625'),
#   Text(176, 0, '20140626'),
#   Text(177, 0, '20140627'),
#   Text(178, 0, '20140628'),
#   Text(179, 0, '20140629'),
#   Text(180, 0, '20140630'),
#   Text(181, 0, '20140701'),
#   Text(182, 0, '20140702'),
#   Text(183, 0, '20140703'),
#   Text(184, 0, '20140704'),
#   Text(185, 0, '20140705'),
#   Text(186, 0, '20140706'),
#   Text(187, 0, '20140707'),
#   Text(188, 0, '20140708'),
#   Text(189, 0, '20140709'),
#   Text(190, 0, '20140710'),
#   Text(191, 0, '20140711'),
#   Text(192, 0, '20140712'),
#   Text(193, 0, '20140713'),
#   Text(194, 0, '20140714'),
#   Text(195, 0, '20140715'),
#   Text(196, 0, '20140716'),
#   Text(197, 0, '20140717'),
#   Text(198, 0, '20140718'),
#   Text(199, 0, '20140719'),
#   Text(200, 0, '20140720'),
#   Text(201, 0, '20140721'),
#   Text(202, 0, '20140722'),
#   Text(203, 0, '20140723'),
#   Text(204, 0, '20140724'),
#   Text(205, 0, '20140725'),
#   Text(206, 0, '20140726'),
#   Text(207, 0, '20140727'),
#   Text(208, 0, '20140728'),
#   Text(209, 0, '20140729'),
#   Text(210, 0, '20140730'),
#   Text(211, 0, '20140731'),
#   Text(212, 0, '20140801'),
#   Text(213, 0, '20140802'),
#   Text(214, 0, '20140803'),
#   Text(215, 0, '20140804'),
#   Text(216, 0, '20140805'),
#   Text(217, 0, '20140806'),
#   Text(218, 0, '20140807'),
#   Text(219, 0, '20140808'),
#   Text(220, 0, '20140809'),
#   Text(221, 0, '20140810'),
#   Text(222, 0, '20140811'),
#   Text(223, 0, '20140812'),
#   Text(224, 0, '20140813'),
#   Text(225, 0, '20140814'),
#   Text(226, 0, '20140815'),
#   Text(227, 0, '20140816'),
#   Text(228, 0, '20140817'),
#   Text(229, 0, '20140818'),
#   Text(230, 0, '20140819'),
#   Text(231, 0, '20140820'),
#   Text(232, 0, '20140821'),
#   Text(233, 0, '20140822'),
#   Text(234, 0, '20140823'),
#   Text(235, 0, '20140824'),
#   Text(236, 0, '20140825'),
#   Text(237, 0, '20140826'),
#   Text(238, 0, '20140827'),
#   Text(239, 0, '20140828'),
#   Text(240, 0, '20140829'),
#   Text(241, 0, '20140830'),
#   Text(242, 0, '20140831'),
#   Text(243, 0, '20140901'),
#   Text(244, 0, '20140902'),
#   Text(245, 0, '20140903'),
#   Text(246, 0, '20140904'),
#   Text(247, 0, '20140905'),
#   Text(248, 0, '20140906'),
#   Text(249, 0, '20140907'),
#   Text(250, 0, '20140908'),
#   Text(251, 0, '20140909'),
#   Text(252, 0, '20140910'),
#   Text(253, 0, '20140911'),
#   Text(254, 0, '20140912'),
#   Text(255, 0, '20140913'),
#   Text(256, 0, '20140914'),
#   Text(257, 0, '20140915'),
#   Text(258, 0, '20140916'),
#   Text(259, 0, '20140917'),
#   Text(260, 0, '20140918'),
#   Text(261, 0, '20140919'),
#   Text(262, 0, '20140920'),
#   Text(263, 0, '20140921'),
#   Text(264, 0, '20140922'),
#   Text(265, 0, '20140923'),
#   Text(266, 0, '20140924'),
#   Text(267, 0, '20140925'),
#   Text(268, 0, '20140926'),
#   Text(269, 0, '20140927'),
#   Text(270, 0, '20140928'),
#   Text(271, 0, '20140929'),
#   Text(272, 0, '20140930'),
#   Text(273, 0, '20141001'),
#   Text(274, 0, '20141002'),
#   Text(275, 0, '20141003'),
#   Text(276, 0, '20141004'),
#   Text(277, 0, '20141005'),
#   Text(278, 0, '20141006'),
#   Text(279, 0, '20141007'),
#   Text(280, 0, '20141008'),
#   Text(281, 0, '20141009'),
#   Text(282, 0, '20141010'),
#   Text(283, 0, '20141011'),
#   Text(284, 0, '20141012'),
#   Text(285, 0, '20141013'),
#   Text(286, 0, '20141014'),
#   Text(287, 0, '20141015'),
#   Text(288, 0, '20141016'),
#   Text(289, 0, '20141017'),
#   Text(290, 0, '20141018'),
#   Text(291, 0, '20141019'),
#   Text(292, 0, '20141020'),
#   Text(293, 0, '20141021'),
#   Text(294, 0, '20141022'),
#   Text(295, 0, '20141023'),
#   Text(296, 0, '20141024'),
#   Text(297, 0, '20141025'),
#   Text(298, 0, '20141026'),
#   Text(299, 0, '20141027'),
#   Text(300, 0, '20141028'),
#   Text(301, 0, '20141029'),
#   Text(302, 0, '20141030'),
#   Text(303, 0, '20141031'),
#   Text(304, 0, '20141101'),
#   Text(305, 0, '20141102'),
#   Text(306, 0, '20141103'),
#   Text(307, 0, '20141104'),
#   Text(308, 0, '20141105'),
#   Text(309, 0, '20141106'),
#   Text(310, 0, '20141107'),
#   Text(311, 0, '20141108'),
#   Text(312, 0, '20141109'),
#   Text(313, 0, '20141110'),
#   Text(314, 0, '20141111'),
#   Text(315, 0, '20141112'),
#   Text(316, 0, '20141113'),
#   Text(317, 0, '20141114'),
#   Text(318, 0, '20141115'),
#   Text(319, 0, '20141116'),
#   Text(320, 0, '20141117'),
#   Text(321, 0, '20141118'),
#   Text(322, 0, '20141119'),
#   Text(323, 0, '20141120'),
#   Text(324, 0, '20141121'),
#   Text(325, 0, '20141122'),
#   Text(326, 0, '20141123'),
#   Text(327, 0, '20141124'),
#   Text(328, 0, '20141125'),
#   Text(329, 0, '20141126'),
#   Text(330, 0, '20141127'),
#   Text(331, 0, '20141128'),
#   Text(332, 0, '20141129'),
#   Text(333, 0, '20141130'),
#   Text(334, 0, '20141201'),
#   Text(335, 0, '20141202'),
#   Text(336, 0, '20141203'),
#   Text(337, 0, '20141204'),
#   Text(338, 0, '20141205'),
#   Text(339, 0, '20141206'),
#   Text(340, 0, '20141207'),
#   Text(341, 0, '20141208'),
#   Text(342, 0, '20141209'),
#   Text(343, 0, '20141210'),
#   Text(344, 0, '20141211'),
#   Text(345, 0, '20141212'),
#   Text(346, 0, '20141213'),
#   Text(347, 0, '20141214'),
#   Text(348, 0, '20141215'),
#   Text(349, 0, '20141216'),
#   Text(350, 0, '20141217'),
#   Text(351, 0, '20141218'),
#   Text(352, 0, '20141219'),
#   Text(353, 0, '20141220'),
#   Text(354, 0, '20141221'),
#   Text(355, 0, '20141222'),
#   Text(356, 0, '20141223'),
#   Text(357, 0, '20141224'),
#   Text(358, 0, '20141225'),
#   Text(359, 0, '20141226'),
#   Text(360, 0, '20141227'),
#   Text(361, 0, '20141228'),
#   Text(362, 0, '20141229'),
#   Text(363, 0, '20141230'),
#   Text(364, 0, '20141231'),
#   Text(365, 0, '20150101'),
#   Text(366, 0, '20150102'),
#   Text(367, 0, '20150103'),
#   Text(368, 0, '20150104'),
#   Text(369, 0, '20150105'),
#   Text(370, 0, '20150106'),
#   Text(371, 0, '20150107'),
#   Text(372, 0, '20150108'),
#   Text(373, 0, '20150109'),
#   Text(374, 0, '20150110'),
#   Text(375, 0, '20150111'),
#   Text(376, 0, '20150112'),
#   Text(377, 0, '20150113'),
#   Text(378, 0, '20150114'),
#   Text(379, 0, '20150115'),
#   Text(380, 0, '20150116'),
#   Text(381, 0, '20150117'),
#   Text(382, 0, '20150118'),
#   Text(383, 0, '20150119'),
#   Text(384, 0, '20150120'),
#   Text(385, 0, '20150121'),
#   Text(386, 0, '20150122'),
#   Text(387, 0, '20150123'),
#   Text(388, 0, '20150124'),
#   Text(389, 0, '20150125'),
#   Text(390, 0, '20150126'),
#   Text(391, 0, '20150127'),
#   Text(392, 0, '20150128'),
#   Text(393, 0, '20150129'),
#   Text(394, 0, '20150130'),
#   Text(395, 0, '20150131'),
#   Text(396, 0, '20150201'),
#   Text(397, 0, '20150202'),
#   Text(398, 0, '20150203'),
#   Text(399, 0, '20150204'),
#   Text(400, 0, '20150205'),
#   Text(401, 0, '20150206'),
#   Text(402, 0, '20150207'),
#   Text(403, 0, '20150208'),
#   Text(404, 0, '20150209'),
#   Text(405, 0, '20150210'),
#   Text(406, 0, '20150211'),
#   Text(407, 0, '20150212'),
#   Text(408, 0, '20150213'),
#   Text(409, 0, '20150214'),
#   Text(410, 0, '20150215'),
#   Text(411, 0, '20150216'),
#   Text(412, 0, '20150217'),
#   Text(413, 0, '20150218'),
#   Text(414, 0, '20150219'),
#   Text(415, 0, '20150220'),
#   Text(416, 0, '20150221'),
#   Text(417, 0, '20150222'),
#   Text(418, 0, '20150223'),
#   Text(419, 0, '20150224'),
#   Text(420, 0, '20150225'),
#   Text(421, 0, '20150226'),
#   Text(422, 0, '20150227'),
#   Text(423, 0, '20150228'),
#   Text(424, 0, '20150301'),
#   Text(425, 0, '20150302'),
#   Text(426, 0, '20150303'),
#   Text(427, 0, '20150304'),
#   Text(428, 0, '20150305'),
#   Text(429, 0, '20150306'),
#   Text(430, 0, '20150307'),
#   Text(431, 0, '20150308'),
#   Text(432, 0, '20150309'),
#   Text(433, 0, '20150310'),
#   Text(434, 0, '20150311'),
#   Text(435, 0, '20150312'),
#   Text(436, 0, '20150313'),
#   Text(437, 0, '20150314'),
#   Text(438, 0, '20150315'),
#   Text(439, 0, '20150316'),
#   Text(440, 0, '20150317'),
#   Text(441, 0, '20150318'),
#   Text(442, 0, '20150319'),
#   Text(443, 0, '20150320'),
#   Text(444, 0, '20150321'),
#   Text(445, 0, '20150322'),
#   Text(446, 0, '20150323'),
#   Text(447, 0, '20150324'),
#   Text(448, 0, '20150325'),
#   Text(449, 0, '20150326'),
#   Text(450, 0, '20150327'),
#   Text(451, 0, '20150328'),
#   Text(452, 0, '20150329'),
#   Text(453, 0, '20150330'),
#   Text(454, 0, '20150331'),
#   Text(455, 0, '20150401'),
#   Text(456, 0, '20150402'),
#   Text(457, 0, '20150403'),
#   Text(458, 0, '20150404'),
#   Text(459, 0, '20150405'),
#   Text(460, 0, '20150406'),
#   Text(461, 0, '20150407'),
#   Text(462, 0, '20150408'),
#   Text(463, 0, '20150409'),
#   Text(464, 0, '20150410'),
#   Text(465, 0, '20150411'),
#   Text(466, 0, '20150412'),
#   Text(467, 0, '20150413'),
#   Text(468, 0, '20150414'),
#   Text(469, 0, '20150415'),
#   Text(470, 0, '20150416'),
#   Text(471, 0, '20150417'),
#   Text(472, 0, '20150418'),
#   Text(473, 0, '20150419'),
#   Text(474, 0, '20150420'),
#   Text(475, 0, '20150421'),
#   Text(476, 0, '20150422'),
#   Text(477, 0, '20150423'),
#   Text(478, 0, '20150424'),
#   Text(479, 0, '20150425'),
#   Text(480, 0, '20150426'),
#   Text(481, 0, '20150427'),
#   Text(482, 0, '20150428'),
#   Text(483, 0, '20150429'),
#   Text(484, 0, '20150430'),
#   Text(485, 0, '20150501'),
#   Text(486, 0, '20150502'),
#   Text(487, 0, '20150503'),
#   Text(488, 0, '20150504'),
#   Text(489, 0, '20150505'),
#   Text(490, 0, '20150506'),
#   Text(491, 0, '20150507'),
#   Text(492, 0, '20150508'),
#   Text(493, 0, '20150509'),
#   Text(494, 0, '20150510'),
#   Text(495, 0, '20150511'),
#   Text(496, 0, '20150512'),
#   Text(497, 0, '20150513'),
#   Text(498, 0, '20150514'),
#   Text(499, 0, '20150515'),
#   Text(500, 0, '20150516'),
#   Text(501, 0, '20150517'),
#   Text(502, 0, '20150518'),
#   Text(503, 0, '20150519'),
#   Text(504, 0, '20150520'),
#   Text(505, 0, '20150521'),
#   Text(506, 0, '20150522'),
#   Text(507, 0, '20150523'),
#   Text(508, 0, '20150524'),
#   Text(509, 0, '20150525'),
#   Text(510, 0, '20150526'),
#   Text(511, 0, '20150527'),
#   Text(512, 0, '20150528'),
#   Text(513, 0, '20150529'),
#   Text(514, 0, '20150530'),
#   Text(515, 0, '20150531'),
#   Text(516, 0, '20150601'),
#   Text(517, 0, '20150602'),
#   Text(518, 0, '20150603'),
#   Text(519, 0, '20150604'),
#   Text(520, 0, '20150605'),
#   Text(521, 0, '20150606'),
#   Text(522, 0, '20150607'),
#   Text(523, 0, '20150608'),
#   Text(524, 0, '20150609'),
#   Text(525, 0, '20150610'),
#   Text(526, 0, '20150611'),
#   Text(527, 0, '20150612'),
#   Text(528, 0, '20150613'),
#   Text(529, 0, '20150614'),
#   Text(530, 0, '20150615'),
#   Text(531, 0, '20150616'),
#   Text(532, 0, '20150617'),
#   Text(533, 0, '20150618'),
#   Text(534, 0, '20150619'),
#   Text(535, 0, '20150620'),
#   Text(536, 0, '20150621'),
#   Text(537, 0, '20150622'),
#   Text(538, 0, '20150623'),
#   Text(539, 0, '20150624'),
#   Text(540, 0, '20150625'),
#   Text(541, 0, '20150626'),
#   Text(542, 0, '20150627'),
#   Text(543, 0, '20150628'),
#   Text(544, 0, '20150629'),
#   Text(545, 0, '20150630'),
#   Text(546, 0, '20150701'),
#   Text(547, 0, '20150702'),
#   Text(548, 0, '20150703'),
#   Text(549, 0, '20150704'),
#   Text(550, 0, '20150705'),
#   Text(551, 0, '20150706'),
#   Text(552, 0, '20150707'),
#   Text(553, 0, '20150708'),
#   Text(554, 0, '20150709'),
#   Text(555, 0, '20150710'),
#   Text(556, 0, '20150711'),
#   Text(557, 0, '20150712'),
#   Text(558, 0, '20150713'),
#   Text(559, 0, '20150714'),
#   Text(560, 0, '20150715'),
#   Text(561, 0, '20150716'),
#   Text(562, 0, '20150717'),
#   Text(563, 0, '20150718'),
#   Text(564, 0, '20150719'),
#   Text(565, 0, '20150720'),
#   Text(566, 0, '20150721'),
#   Text(567, 0, '20150722'),
#   Text(568, 0, '20150723'),
#   Text(569, 0, '20150724'),
#   Text(570, 0, '20150725'),
#   Text(571, 0, '20150726'),
#   Text(572, 0, '20150727'),
#   Text(573, 0, '20150728'),
#   Text(574, 0, '20150729'),
#   Text(575, 0, '20150730'),
#   Text(576, 0, '20150731'),
#   Text(577, 0, '20150801'),
#   Text(578, 0, '20150802'),
#   Text(579, 0, '20150803'),
#   Text(580, 0, '20150804'),
#   Text(581, 0, '20150805'),
#   Text(582, 0, '20150806'),
#   Text(583, 0, '20150807'),
#   Text(584, 0, '20150808'),
#   Text(585, 0, '20150809'),
#   Text(586, 0, '20150810'),
#   Text(587, 0, '20150811'),
#   Text(588, 0, '20150812'),
#   Text(589, 0, '20150813'),
#   Text(590, 0, '20150814'),
#   Text(591, 0, '20150815'),
#   Text(592, 0, '20150816'),
#   Text(593, 0, '20150817'),
#   Text(594, 0, '20150818'),
#   Text(595, 0, '20150819'),
#   Text(596, 0, '20150820'),
#   Text(597, 0, '20150821'),
#   Text(598, 0, '20150822'),
#   Text(599, 0, '20150823'),
#   Text(600, 0, '20150824'),
#   Text(601, 0, '20150825'),
#   Text(602, 0, '20150826'),
#   Text(603, 0, '20150827'),
#   Text(604, 0, '20150828'),
#   Text(605, 0, '20150829'),
#   Text(606, 0, '20150830'),
#   Text(607, 0, '20150831'),
#   Text(608, 0, '20150901'),
#   Text(609, 0, '20150902'),
#   Text(610, 0, '20150903'),
#   Text(611, 0, '20150904'),
#   Text(612, 0, '20150905'),
#   Text(613, 0, '20150906'),
#   Text(614, 0, '20150907'),
#   Text(615, 0, '20150908'),
#   Text(616, 0, '20150909'),
#   Text(617, 0, '20150910'),
#   Text(618, 0, '20150911'),
#   Text(619, 0, '20150912'),
#   Text(620, 0, '20150913'),
#   Text(621, 0, '20150914'),
#   Text(622, 0, '20150915'),
#   Text(623, 0, '20150916'),
#   Text(624, 0, '20150917'),
#   Text(625, 0, '20150918'),
#   Text(626, 0, '20150919'),
#   Text(627, 0, '20150920'),
#   Text(628, 0, '20150921'),
#   Text(629, 0, '20150922'),
#   Text(630, 0, '20150923'),
#   Text(631, 0, '20150924'),
#   Text(632, 0, '20150925'),
#   Text(633, 0, '20150926'),
#   Text(634, 0, '20150927'),
#   Text(635, 0, '20150928'),
#   Text(636, 0, '20150929'),
#   Text(637, 0, '20150930'),
#   Text(638, 0, '20151001'),
#   Text(639, 0, '20151002'),
#   Text(640, 0, '20151003'),
#   Text(641, 0, '20151004'),
#   Text(642, 0, '20151005'),
#   Text(643, 0, '20151006'),
#   Text(644, 0, '20151007'),
#   Text(645, 0, '20151008'),
#   Text(646, 0, '20151009'),
#   Text(647, 0, '20151010'),
#   Text(648, 0, '20151011'),
#   Text(649, 0, '20151012'),
#   Text(650, 0, '20151013'),
#   Text(651, 0, '20151014'),
#   Text(652, 0, '20151015'),
#   Text(653, 0, '20151016'),
#   Text(654, 0, '20151017'),
#   Text(655, 0, '20151018'),
#   Text(656, 0, '20151019'),
#   Text(657, 0, '20151020'),
#   Text(658, 0, '20151021'),
#   Text(659, 0, '20151022'),
#   Text(660, 0, '20151023'),
#   Text(661, 0, '20151024'),
#   Text(662, 0, '20151025'),
#   Text(663, 0, '20151026'),
#   Text(664, 0, '20151027'),
#   Text(665, 0, '20151028'),
#   Text(666, 0, '20151029'),
#   Text(667, 0, '20151030'),
#   Text(668, 0, '20151031'),
#   Text(669, 0, '20151101'),
#   Text(670, 0, '20151102'),
#   Text(671, 0, '20151103'),
#   Text(672, 0, '20151104'),
#   Text(673, 0, '20151105'),
#   Text(674, 0, '20151106'),
#   Text(675, 0, '20151107'),
#   Text(676, 0, '20151108'),
#   Text(677, 0, '20151109'),
#   Text(678, 0, '20151110'),
#   Text(679, 0, '20151111'),
#   Text(680, 0, '20151112'),
#   Text(681, 0, '20151113'),
#   Text(682, 0, '20151114'),
#   Text(683, 0, '20151115'),
#   Text(684, 0, '20151116'),
#   Text(685, 0, '20151117'),
#   Text(686, 0, '20151118'),
#   Text(687, 0, '20151119'),
#   Text(688, 0, '20151120'),
#   Text(689, 0, '20151121'),
#   Text(690, 0, '20151122'),
#   Text(691, 0, '20151123'),
#   Text(692, 0, '20151124'),
#   Text(693, 0, '20151125'),
#   Text(694, 0, '20151126'),
#   Text(695, 0, '20151127'),
#   Text(696, 0, '20151128'),
#   Text(697, 0, '20151129'),
#   Text(698, 0, '20151130'),
#   Text(699, 0, '20151201'),
#   Text(700, 0, '20151202'),
#   Text(701, 0, '20151203'),
#   Text(702, 0, '20151204'),
#   Text(703, 0, '20151205'),
#   Text(704, 0, '20151206'),
#   Text(705, 0, '20151207'),
#   Text(706, 0, '20151208'),
#   Text(707, 0, '20151209'),
#   Text(708, 0, '20151210'),
#   Text(709, 0, '20151211'),
#   Text(710, 0, '20151212'),
#   Text(711, 0, '20151213'),
#   Text(712, 0, '20151214'),
#   Text(713, 0, '20151215'),
#   Text(714, 0, '20151216'),
#   Text(715, 0, '20151217'),
#   Text(716, 0, '20151218'),
#   Text(717, 0, '20151219'),
#   Text(718, 0, '20151220'),
#   Text(719, 0, '20151221'),
#   Text(720, 0, '20151222'),
#   Text(721, 0, '20151223'),
#   Text(722, 0, '20151224'),
#   Text(723, 0, '20151225'),
#   Text(724, 0, '20151226'),
#   Text(725, 0, '20151227'),
#   Text(726, 0, '20151228'),
#   Text(727, 0, '20151229'),
#   Text(728, 0, '20151230'),
#   Text(729, 0, '20151231'),
#   Text(730, 0, '20160101'),
#   Text(731, 0, '20160102'),
#   Text(732, 0, '20160103'),
#   Text(733, 0, '20160104'),
#   Text(734, 0, '20160105'),
#   Text(735, 0, '20160106'),
#   Text(736, 0, '20160107'),
#   Text(737, 0, '20160108'),
#   Text(738, 0, '20160109'),
#   Text(739, 0, '20160110'),
#   Text(740, 0, '20160111'),
#   Text(741, 0, '20160112'),
#   Text(742, 0, '20160113'),
#   Text(743, 0, '20160114'),
#   Text(744, 0, '20160115'),
#   Text(745, 0, '20160116'),
#   Text(746, 0, '20160117'),
#   Text(747, 0, '20160118'),
#   Text(748, 0, '20160119'),
#   Text(749, 0, '20160120'),
#   Text(750, 0, '20160121'),
#   Text(751, 0, '20160122'),
#   Text(752, 0, '20160123'),
#   Text(753, 0, '20160124'),
#   Text(754, 0, '20160125'),
#   Text(755, 0, '20160126'),
#   Text(756, 0, '20160127'),
#   Text(757, 0, '20160128'),
#   Text(758, 0, '20160129'),
#   Text(759, 0, '20160130'),
#   Text(760, 0, '20160131'),
#   Text(761, 0, '20160201'),
#   Text(762, 0, '20160202'),
#   Text(763, 0, '20160203'),
#   Text(764, 0, '20160204'),
#   Text(765, 0, '20160205'),
#   Text(766, 0, '20160206'),
#   Text(767, 0, '20160207'),
#   Text(768, 0, '20160208'),
#   Text(769, 0, '20160209'),
#   Text(770, 0, '20160210'),
#   Text(771, 0, '20160211'),
#   Text(772, 0, '20160212'),
#   Text(773, 0, '20160213'),
#   Text(774, 0, '20160214'),
#   Text(775, 0, '20160215'),
#   Text(776, 0, '20160216'),
#   Text(777, 0, '20160217'),
#   Text(778, 0, '20160218'),
#   Text(779, 0, '20160219'),
#   Text(780, 0, '20160220'),
#   Text(781, 0, '20160221'),
#   Text(782, 0, '20160222'),
#   Text(783, 0, '20160223'),
#   Text(784, 0, '20160224'),
#   Text(785, 0, '20160225'),
#   Text(786, 0, '20160226'),
#   Text(787, 0, '20160227'),
#   Text(788, 0, '20160228'),
#   Text(789, 0, '20160229'),
#   Text(790, 0, '20160301'),
#   Text(791, 0, '20160302'),
#   Text(792, 0, '20160303'),
#   Text(793, 0, '20160304'),
#   Text(794, 0, '20160305'),
#   Text(795, 0, '20160306'),
#   Text(796, 0, '20160307'),
#   Text(797, 0, '20160308'),
#   Text(798, 0, '20160309'),
#   Text(799, 0, '20160310'),
#   Text(800, 0, '20160311'),
#   Text(801, 0, '20160312'),
#   Text(802, 0, '20160313'),
#   Text(803, 0, '20160314'),
#   Text(804, 0, '20160315'),
#   Text(805, 0, '20160316'),
#   Text(806, 0, '20160317'),
#   Text(807, 0, '20160318'),
#   Text(808, 0, '20160319'),
#   Text(809, 0, '20160320'),
#   Text(810, 0, '20160321'),
#   Text(811, 0, '20160322'),
#   Text(812, 0, '20160323'),
#   Text(813, 0, '20160324'),
#   Text(814, 0, '20160325'),
#   Text(815, 0, '20160326'),
#   Text(816, 0, '20160327'),
#   Text(817, 0, '20160328'),
#   Text(818, 0, '20160329'),
#   Text(819, 0, '20160330'),
#   Text(820, 0, '20160331'),
#   Text(821, 0, '20160401'),
#   Text(822, 0, '20160402'),
#   Text(823, 0, '20160403'),
#   Text(824, 0, '20160404'),
#   Text(825, 0, '20160405'),
#   Text(826, 0, '20160406'),
#   Text(827, 0, '20160407'),
#   Text(828, 0, '20160408'),
#   Text(829, 0, '20160409'),
#   Text(830, 0, '20160410'),
#   Text(831, 0, '20160411'),
#   Text(832, 0, '20160412'),
#   Text(833, 0, '20160413'),
#   Text(834, 0, '20160414'),
#   Text(835, 0, '20160415'),
#   Text(836, 0, '20160416'),
#   Text(837, 0, '20160417'),
#   Text(838, 0, '20160418'),
#   Text(839, 0, '20160419'),
#   Text(840, 0, '20160420'),
#   Text(841, 0, '20160421'),
#   Text(842, 0, '20160422'),
#   Text(843, 0, '20160423'),
#   Text(844, 0, '20160424'),
#   Text(845, 0, '20160425'),
#   Text(846, 0, '20160426'),
#   Text(847, 0, '20160427'),
#   Text(848, 0, '20160428'),
#   Text(849, 0, '20160429'),
#   Text(850, 0, '20160430'),
#   Text(851, 0, '20160501'),
#   Text(852, 0, '20160502'),
#   Text(853, 0, '20160503'),
#   Text(854, 0, '20160504'),
#   Text(855, 0, '20160505'),
#   Text(856, 0, '20160506'),
#   Text(857, 0, '20160507'),
#   Text(858, 0, '20160508'),
#   Text(859, 0, '20160509'),
#   Text(860, 0, '20160510'),
#   Text(861, 0, '20160511'),
#   Text(862, 0, '20160512'),
#   Text(863, 0, '20160513'),
#   Text(864, 0, '20160514'),
#   Text(865, 0, '20160515'),
#   Text(866, 0, '20160516'),
#   Text(867, 0, '20160517'),
#   Text(868, 0, '20160518'),
#   Text(869, 0, '20160519'),
#   Text(870, 0, '20160520'),
#   Text(871, 0, '20160521'),
#   Text(872, 0, '20160522'),
#   Text(873, 0, '20160523'),
#   Text(874, 0, '20160524'),
#   Text(875, 0, '20160525'),
#   Text(876, 0, '20160526'),
#   Text(877, 0, '20160527'),
#   Text(878, 0, '20160528'),
#   Text(879, 0, '20160529'),
#   Text(880, 0, '20160530'),
#   Text(881, 0, '20160531'),
#   Text(882, 0, '20160601'),
#   Text(883, 0, '20160602'),
#   Text(884, 0, '20160603'),
#   Text(885, 0, '20160604'),
#   Text(886, 0, '20160605'),
#   Text(887, 0, '20160606'),
#   Text(888, 0, '20160607'),
#   Text(889, 0, '20160608'),
#   Text(890, 0, '20160609'),
#   Text(891, 0, '20160610'),
#   Text(892, 0, '20160611'),
#   Text(893, 0, '20160612'),
#   Text(894, 0, '20160613'),
#   Text(895, 0, '20160614'),
#   Text(896, 0, '20160615'),
#   Text(897, 0, '20160616'),
#   Text(898, 0, '20160617'),
#   Text(899, 0, '20160618'),
#   Text(900, 0, '20160619'),
#   Text(901, 0, '20160620'),
#   Text(902, 0, '20160621'),
#   Text(903, 0, '20160622'),
#   Text(904, 0, '20160623'),
#   Text(905, 0, '20160624'),
#   Text(906, 0, '20160625'),
#   Text(907, 0, '20160626'),
#   Text(908, 0, '20160627'),
#   Text(909, 0, '20160628'),
#   Text(910, 0, '20160629'),
#   Text(911, 0, '20160630'),
#   Text(912, 0, '20160701'),
#   Text(913, 0, '20160702'),
#   Text(914, 0, '20160703'),
#   Text(915, 0, '20160704'),
#   Text(916, 0, '20160705'),
#   Text(917, 0, '20160706'),
#   Text(918, 0, '20160707'),
#   Text(919, 0, '20160708'),
#   Text(920, 0, '20160709'),
#   Text(921, 0, '20160710'),
#   Text(922, 0, '20160711'),
#   Text(923, 0, '20160712'),
#   Text(924, 0, '20160713'),
#   Text(925, 0, '20160714'),
#   Text(926, 0, '20160715'),
#   Text(927, 0, '20160716'),
#   Text(928, 0, '20160717'),
#   Text(929, 0, '20160718'),
#   Text(930, 0, '20160719'),
#   Text(931, 0, '20160720'),
#   Text(932, 0, '20160721'),
#   Text(933, 0, '20160722'),
#   Text(934, 0, '20160723'),
#   Text(935, 0, '20160724'),
#   Text(936, 0, '20160725'),
#   Text(937, 0, '20160726'),
#   Text(938, 0, '20160727'),
#   Text(939, 0, '20160728'),
#   Text(940, 0, '20160729'),
#   Text(941, 0, '20160730'),
#   Text(942, 0, '20160731'),
#   Text(943, 0, '20160801'),
#   Text(944, 0, '20160802'),
#   Text(945, 0, '20160803'),
#   Text(946, 0, '20160804'),
#   Text(947, 0, '20160805'),
#   Text(948, 0, '20160806'),
#   Text(949, 0, '20160807'),
#   Text(950, 0, '20160808'),
#   Text(951, 0, '20160809'),
#   Text(952, 0, '20160810'),
#   Text(953, 0, '20160811'),
#   Text(954, 0, '20160812'),
#   Text(955, 0, '20160813'),
#   Text(956, 0, '20160814'),
#   Text(957, 0, '20160815'),
#   Text(958, 0, '20160816'),
#   Text(959, 0, '20160817'),
#   Text(960, 0, '20160818'),
#   Text(961, 0, '20160819'),
#   Text(962, 0, '20160820'),
#   Text(963, 0, '20160821'),
#   Text(964, 0, '20160822'),
#   Text(965, 0, '20160823'),
#   Text(966, 0, '20160824'),
#   Text(967, 0, '20160825'),
#   Text(968, 0, '20160826'),
#   Text(969, 0, '20160827'),
#   Text(970, 0, '20160828'),
#   Text(971, 0, '20160829'),
#   Text(972, 0, '20160830'),
#   Text(973, 0, '20160831'),
#   Text(974, 0, '20160901'),
#   Text(975, 0, '20160902'),
#   Text(976, 0, '20160903'),
#   Text(977, 0, '20160904'),
#   Text(978, 0, '20160905'),
#   Text(979, 0, '20160906'),
#   Text(980, 0, '20160907'),
#   Text(981, 0, '20160908'),
#   Text(982, 0, '20160909'),
#   Text(983, 0, '20160910'),
#   Text(984, 0, '20160911'),
#   Text(985, 0, '20160912'),
#   Text(986, 0, '20160913'),
#   Text(987, 0, '20160914'),
#   Text(988, 0, '20160915'),
#   Text(989, 0, '20160916'),
#   Text(990, 0, '20160917'),
#   Text(991, 0, '20160918'),
#   Text(992, 0, '20160919'),
#   Text(993, 0, '20160920'),
#   Text(994, 0, '20160921'),
#   Text(995, 0, '20160922'),
#   Text(996, 0, '20160923'),
#   Text(997, 0, '20160924'),
#   Text(998, 0, '20160925'),
#   Text(999, 0, '20160926'),
#   ...])

# %%
# 변수 별 상관관계
corr = train.corr()

# %%
# 서울 미세먼지를 기준으로 각 변수와의 상관관계
corr['Seoul'].sort_values(ascending=False)
# Out:
# Seoul          1.000000
# Weihai         0.464319
# Tianjin        0.311740
# W_direction    0.158552
# W_speed       -0.021202
# Date          -0.138808
# Humidity      -0.171488
# Temperature   -0.245954
# Name: Seoul, dtype: float64

# %%
# 각 변수간의 관계를 한번에 출력하는 히트맵
plt.figure(figsize=(20, 20))
df_heatmap = sns.heatmap(corr, cbar=True, annot=True,
                        annot_kws={'size':10}, fmt = '.2f', square=True, cmap='hot')

# %%
# 온도와 서울 미세먼지 관계 확인
plt.plot('Temperature', 'Seoul', data=train, linestyle='none', marker='o',
        markersize=3, color='blue', alpha=0.5)

plt.xlabel('Temperature', fontsize=10)
plt.ylabel('Seoul', fontsize=10)

plt.show()

# %%
# 풍향와 서울 미세먼지 관계 확인
plt.plot('W_direction', 'Seoul', data=train, linestyle='none', marker='o',
        markersize=3, color='red', alpha=0.5)

plt.xlabel('W_direction', fontsize=10)
plt.ylabel('Seoul', fontsize=10)

plt.show()

# %%
from keras.models import Sequential # Sequential : layer를 선형으로 쌓음
from keras.layers import Dense, LSTM # Dense : 계산 수행 layer

# %%
# 서울 미세먼지 array로 변환
from numpy import array

Seoul = array(train['Seoul'])
Weihai = array(train['Weihai'])

# %%
# 난수 seed 생성
np.random.seed(777)

# %%
# LSTM의 입력에 대한 출력을 매핑하는 작업 시작
# 시계열 예측을 위한 다층 퍼셉트론 모델 함수
# 위에서 생성한 array를 샘플이라고 하는 여러 입력 / 출력의 패턴으로 분할
# 5개가 입력되고 그 다음 1개가 출력으로 사용되는 방식
steps = 5
features = 1

def split_sequence(sequence, steps):
    X, y = list(), list()
    for i in range(len(sequence)):
        end_index = i + steps
        
        if end_index > len(sequence) - 1:
            break
        seq_x, seq_y = sequence[i:end_index], sequence[end_index]
        X.append(seq_x)
        y.append(seq_y)
        
    return array(X), array(y)

# %%
# 각 array가 2557개에서 steps 수를 제외한 2552개의 array로 변함
x_Seoul, y_Seoul = split_sequence(Seoul, steps)
print(x_Seoul.shape, y_Seoul.shape)
# Out:
# (2552, 5) (2552,)

# %%
x_Weihai, y_Weihai = split_sequence(Weihai, steps)
print(x_Weihai.shape, y_Weihai.shape)
# Out:
# (2552, 5) (2552,)

# %%
x_Seoul
# Out:
# array([[125,  56,  59,  51,  45],
#        [ 56,  59,  51,  45,  69],
#        [ 59,  51,  45,  69,  85],
#        ...,
#        [ 68,  30,  62,  73,  76],
#        [ 30,  62,  73,  76,  79],
#        [ 62,  73,  76,  79,  42]], dtype=int64)

# %%
# reshape : 배열 재구조
x_Seoul = x_Seoul.reshape((x_Seoul.shape[0], x_Seoul.shape[1], features))
x_Weihai = x_Weihai.reshape((x_Weihai.shape[0], x_Weihai.shape[1], features))

# %%
# reshape를 통해 2차원 array로 변환된 것 확인
x_Seoul
# Out:
# array([[[125],
#         [ 56],
#         [ 59],
#         [ 51],
#         [ 45]],
#
#        [[ 56],
#         [ 59],
#         [ 51],
#         [ 45],
#         [ 69]],
#
#        [[ 59],
#         [ 51],
#         [ 45],
#         [ 69],
#         [ 85]],
#
#        ...,
#
#        [[ 68],
#         [ 30],
#         [ 62],
#         [ 73],
#         [ 76]],
#
#        [[ 30],
#         [ 62],
#         [ 73],
#         [ 76],
#         [ 79]],
#
#        [[ 62],
#         [ 73],
#         [ 76],
#         [ 79],
#         [ 42]]], dtype=int64)

# %%
# model
model = Sequential()
model.add(LSTM(300, activation='relu', input_shape=(steps, features))) # relu함수 사용
model.add(Dense(1)) # 출력 layer가 1개

model.compile(optimizer='adam', loss='mse') # train과정 : adam, 손실함수 : mse(최소제곱오차)

histogram = model.fit(x_Seoul, y_Seoul, epochs=50, batch_size=100, verbose=1) # verbose : 진행과정 표시
# Out:
# Epoch 1/50
# 26/26 [==============================] - 1s 14ms/step - loss: 1588.0907
# Epoch 2/50
# 26/26 [==============================] - 0s 14ms/step - loss: 493.5493
# Epoch 3/50
# 26/26 [==============================] - 0s 15ms/step - loss: 591.2166
# Epoch 4/50
# 26/26 [==============================] - 0s 14ms/step - loss: 276.4094
# Epoch 5/50
# 26/26 [==============================] - 0s 14ms/step - loss: 307.7266
# Epoch 6/50
# 26/26 [==============================] - 0s 15ms/step - loss: 492.9335
# Epoch 7/50
# 26/26 [==============================] - 0s 14ms/step - loss: 304.6250
# Epoch 8/50
# 26/26 [==============================] - 0s 14ms/step - loss: 330.1093
# Epoch 9/50
# 26/26 [==============================] - 0s 15ms/step - loss: 330.9864
# Epoch 10/50
# 26/26 [==============================] - 0s 14ms/step - loss: 374.7668
# Epoch 11/50
# 26/26 [==============================] - 0s 14ms/step - loss: 269.1435
# Epoch 12/50
# 26/26 [==============================] - 0s 15ms/step - loss: 390.5212
# Epoch 13/50
# 26/26 [==============================] - 0s 14ms/step - loss: 362.7113
# Epoch 14/50
# 26/26 [==============================] - 0s 15ms/step - loss: 284.2438
# Epoch 15/50
# 26/26 [==============================] - 0s 14ms/step - loss: 310.3394
# Epoch 16/50
# 26/26 [==============================] - 0s 14ms/step - loss: 277.1571
# Epoch 17/50
# 26/26 [==============================] - 0s 15ms/step - loss: 317.3030
# Epoch 18/50
# 26/26 [==============================] - 0s 14ms/step - loss: 315.4146
# Epoch 19/50
# 26/26 [==============================] - 0s 14ms/step - loss: 331.2843
# Epoch 20/50
# 26/26 [==============================] - 0s 14ms/step - loss: 286.8652
# Epoch 21/50
# 26/26 [==============================] - 0s 14ms/step - loss: 372.4797
# Epoch 22/50
# 26/26 [==============================] - 0s 15ms/step - loss: 314.1918
# Epoch 23/50
# 26/26 [==============================] - 0s 14ms/step - loss: 307.8446
# Epoch 24/50
# 26/26 [==============================] - 0s 14ms/step - loss: 268.5998
# Epoch 25/50
# 26/26 [==============================] - 0s 15ms/step - loss: 278.0825
# Epoch 26/50
# 26/26 [==============================] - 0s 14ms/step - loss: 346.0576
# Epoch 27/50
# 26/26 [==============================] - 0s 14ms/step - loss: 350.0576
# Epoch 28/50
# 26/26 [==============================] - 0s 16ms/step - loss: 355.7012
# Epoch 29/50
# 26/26 [==============================] - 0s 14ms/step - loss: 355.6554
# Epoch 30/50
# 26/26 [==============================] - 0s 15ms/step - loss: 297.7514
# Epoch 31/50
# 26/26 [==============================] - 0s 16ms/step - loss: 287.0028
# Epoch 32/50
# 26/26 [==============================] - 0s 14ms/step - loss: 282.4047
# Epoch 33/50
# 26/26 [==============================] - 0s 15ms/step - loss: 268.4432
# Epoch 34/50
# 26/26 [==============================] - 0s 14ms/step - loss: 319.6157
# Epoch 35/50
# 26/26 [==============================] - 0s 14ms/step - loss: 302.6821
# Epoch 36/50
# 26/26 [==============================] - 0s 14ms/step - loss: 292.0282
# Epoch 37/50
# 26/26 [==============================] - 0s 14ms/step - loss: 291.3795
# Epoch 38/50
# 26/26 [==============================] - 0s 15ms/step - loss: 262.6838
# Epoch 39/50
# 26/26 [==============================] - 0s 13ms/step - loss: 279.0741
# Epoch 40/50
# 26/26 [==============================] - 0s 13ms/step - loss: 299.0786
# Epoch 41/50
# 26/26 [==============================] - 0s 14ms/step - loss: 357.4445
# Epoch 42/50
# 26/26 [==============================] - 0s 14ms/step - loss: 337.3100
# Epoch 43/50
# 26/26 [==============================] - 0s 14ms/step - loss: 285.4064
# Epoch 44/50
# 26/26 [==============================] - 0s 15ms/step - loss: 274.2977
# Epoch 45/50
# 26/26 [==============================] - 0s 14ms/step - loss: 245.3095
# Epoch 46/50
# 26/26 [==============================] - 0s 14ms/step - loss: 264.2021
# Epoch 47/50
# 26/26 [==============================] - 0s 14ms/step - loss: 273.9494
# Epoch 48/50
# 26/26 [==============================] - 0s 14ms/step - loss: 234.7223
# Epoch 49/50
# 26/26 [==============================] - 0s 14ms/step - loss: 272.1623
# Epoch 50/50
# 26/26 [==============================] - 0s 13ms/step - loss: 277.3723

# %%
# test_dust.csv
test = pd.read_csv('raw_test.csv')

# %%
test.head()
# Out:
#        Date  Temperature  W_speed  W_direction  Humidity  Tianjin  Weihai  \
# 0  20210101         -4.2      2.0          270      64.0       70      53
# 1  20210102         -5.0      2.6          270      38.5       61      53
# 2  20210103         -5.6      2.0          270      45.0       66      54
# 3  20210104         -3.5      1.7           50      51.4       44      51
# 4  20210105         -5.5      2.9          290      52.8       27      35
#
#    Seoul
# 0     32
# 1     39
# 2     44
# 3     46
# 4     34

# %%
# test의 서울 미세먼지를 array로 생성
test_Seoul = array(test['Seoul'])
x_test, y_test = split_sequence(test_Seoul, steps)

# %%
x_test
# Out:
# array([[ 32,  39,  44,  46,  34],
#        [ 39,  44,  46,  34,  28],
#        [ 44,  46,  34,  28,  44],
#        [ 46,  34,  28,  44,  23],
#        [ 34,  28,  44,  23,  30],
#        [ 28,  44,  23,  30,  41],
#        [ 44,  23,  30,  41,  54],
#        [ 23,  30,  41,  54,  72],
#        [ 30,  41,  54,  72, 112],
#        [ 41,  54,  72, 112,  83],
#        [ 54,  72, 112,  83,  86],
#        [ 72, 112,  83,  86,  52],
#        [112,  83,  86,  52,  22],
#        [ 83,  86,  52,  22,  42],
#        [ 86,  52,  22,  42,  38],
#        [ 52,  22,  42,  38,  52],
#        [ 22,  42,  38,  52,  62],
#        [ 42,  38,  52,  62,  53],
#        [ 38,  52,  62,  53,   9],
#        [ 52,  62,  53,   9,  15],
#        [ 62,  53,   9,  15,  28],
#        [ 53,   9,  15,  28,  56],
#        [  9,  15,  28,  56,  45],
#        [ 15,  28,  56,  45,  44],
#        [ 28,  56,  45,  44,  28],
#        [ 56,  45,  44,  28,  59],
#        [ 45,  44,  28,  59,  64],
#        [ 44,  28,  59,  64,  76],
#        [ 28,  59,  64,  76,  36],
#        [ 59,  64,  76,  36,  40],
#        [ 64,  76,  36,  40,  30],
#        [ 76,  36,  40,  30,  34],
#        [ 36,  40,  30,  34,  81],
#        [ 40,  30,  34,  81,  92],
#        [ 30,  34,  81,  92,  32],
#        [ 34,  81,  92,  32,  28],
#        [ 81,  92,  32,  28,  46],
#        [ 92,  32,  28,  46,  84],
#        [ 32,  28,  46,  84,  98],
#        [ 28,  46,  84,  98,  97],
#        [ 46,  84,  98,  97,  94],
#        [ 84,  98,  97,  94,  64],
#        [ 98,  97,  94,  64,  30],
#        [ 97,  94,  64,  30,  54],
#        [ 94,  64,  30,  54,  51],
#        [ 64,  30,  54,  51,  58],
#        [ 30,  54,  51,  58,  82],
#        [ 54,  51,  58,  82,  88],
#        [ 51,  58,  82,  88,  63],
#        [ 58,  82,  88,  63,  60],
#        [ 82,  88,  63,  60,  60],
#        [ 88,  63,  60,  60,  65],
#        [ 63,  60,  60,  65,  42],
#        [ 60,  60,  65,  42,  20],
#        [ 60,  65,  42,  20,  28],
#        [ 65,  42,  20,  28,  16],
#        [ 42,  20,  28,  16,  14],
#        [ 20,  28,  16,  14,  50],
#        [ 28,  16,  14,  50,  58],
#        [ 16,  14,  50,  58,  50],
#        [ 14,  50,  58,  50,  36],
#        [ 50,  58,  50,  36,  30],
#        [ 58,  50,  36,  30,  51],
#        [ 50,  36,  30,  51,  56],
#        [ 36,  30,  51,  56, 103],
#        [ 30,  51,  56, 103, 126],
#        [ 51,  56, 103, 126,  74],
#        [ 56, 103, 126,  74,  64],
#        [103, 126,  74,  64,  92],
#        [126,  74,  64,  92, 100],
#        [ 74,  64,  92, 100, 102],
#        [ 64,  92, 100, 102, 100],
#        [ 92, 100, 102, 100, 106],
#        [100, 102, 100, 106,  76],
#        [102, 100, 106,  76,  38],
#        [100, 106,  76,  38,  52],
#        [106,  76,  38,  52,  45],
#        [ 76,  38,  52,  45,  90],
#        [ 38,  52,  45,  90,  74],
#        [ 52,  45,  90,  74,  77],
#        [ 45,  90,  74,  77, 124],
#        [ 90,  74,  77, 124,  82],
#        [ 74,  77, 124,  82,  19],
#        [ 77, 124,  82,  19, 298],
#        [124,  82,  19, 298, 148],
#        [ 82,  19, 298, 148,  49],
#        [ 19, 298, 148,  49,  48],
#        [298, 148,  49,  48,  52],
#        [148,  49,  48,  52,  42],
#        [ 49,  48,  52,  42,  10],
#        [ 48,  52,  42,  10,  26],
#        [ 52,  42,  10,  26,  49],
#        [ 42,  10,  26,  49,  64],
#        [ 10,  26,  49,  64,  39],
#        [ 26,  49,  64,  39,  38],
#        [ 49,  64,  39,  38,  40],
#        [ 64,  39,  38,  40,  53],
#        [ 39,  38,  40,  53,  50],
#        [ 38,  40,  53,  50,  20],
#        [ 40,  53,  50,  20,  39],
#        [ 53,  50,  20,  39,  61],
#        [ 50,  20,  39,  61,  82],
#        [ 20,  39,  61,  82,  89],
#        [ 39,  61,  82,  89,  42],
#        [ 61,  82,  89,  42,  57],
#        [ 82,  89,  42,  57,  67],
#        [ 89,  42,  57,  67,  75],
#        [ 42,  57,  67,  75,  74],
#        [ 57,  67,  75,  74,  42],
#        [ 67,  75,  74,  42,  24],
#        [ 75,  74,  42,  24,  26],
#        [ 74,  42,  24,  26,  30],
#        [ 42,  24,  26,  30,  34],
#        [ 24,  26,  30,  34,  58],
#        [ 26,  30,  34,  58,  61],
#        [ 30,  34,  58,  61,  38],
#        [ 34,  58,  61,  38,  30],
#        [ 58,  61,  38,  30,  18],
#        [ 61,  38,  30,  18,  39],
#        [ 38,  30,  18,  39,  33],
#        [ 30,  18,  39,  33,  40],
#        [ 18,  39,  33,  40,  62],
#        [ 39,  33,  40,  62, 302],
#        [ 33,  40,  62, 302, 393],
#        [ 40,  62, 302, 393,  50],
#        [ 62, 302, 393,  50,  23],
#        [302, 393,  50,  23,  22],
#        [393,  50,  23,  22,  24],
#        [ 50,  23,  22,  24,  46],
#        [ 23,  22,  24,  46,  57],
#        [ 22,  24,  46,  57,  56],
#        [ 24,  46,  57,  56,  10],
#        [ 46,  57,  56,  10,  14],
#        [ 57,  56,  10,  14,  35],
#        [ 56,  10,  14,  35,  38],
#        [ 10,  14,  35,  38,  26],
#        [ 14,  35,  38,  26,  18],
#        [ 35,  38,  26,  18,  34],
#        [ 38,  26,  18,  34,  45],
#        [ 26,  18,  34,  45, 100],
#        [ 18,  34,  45, 100,  85],
#        [ 34,  45, 100,  85,  47],
#        [ 45, 100,  85,  47,  48],
#        [100,  85,  47,  48,  45],
#        [ 85,  47,  48,  45,  21],
#        [ 47,  48,  45,  21,  27],
#        [ 48,  45,  21,  27,  38],
#        [ 45,  21,  27,  38,  46],
#        [ 21,  27,  38,  46,  58],
#        [ 27,  38,  46,  58,  40],
#        [ 38,  46,  58,  40,  31],
#        [ 46,  58,  40,  31,  52],
#        [ 58,  40,  31,  52,  66],
#        [ 40,  31,  52,  66,  42],
#        [ 31,  52,  66,  42,  51],
#        [ 52,  66,  42,  51,  44],
#        [ 66,  42,  51,  44,  56],
#        [ 42,  51,  44,  56,  25],
#        [ 51,  44,  56,  25,  28],
#        [ 44,  56,  25,  28,  34],
#        [ 56,  25,  28,  34,  48],
#        [ 25,  28,  34,  48,  33],
#        [ 28,  34,  48,  33,  14],
#        [ 34,  48,  33,  14,  22],
#        [ 48,  33,  14,  22,  24],
#        [ 33,  14,  22,  24,  56],
#        [ 14,  22,  24,  56,  57],
#        [ 22,  24,  56,  57,  50],
#        [ 24,  56,  57,  50,  28],
#        [ 56,  57,  50,  28,  20],
#        [ 57,  50,  28,  20,  36],
#        [ 50,  28,  20,  36,  47],
#        [ 28,  20,  36,  47,  26],
#        [ 20,  36,  47,  26,  22],
#        [ 36,  47,  26,  22,  22],
#        [ 47,  26,  22,  22,  32]], dtype=int64)

# %%
x_test = x_test.reshape((x_test.shape[0], x_test.shape[1], features))
y_hat_test = model.predict(x_test)

# %%
# 예측 모델 출력
plt.figure(figsize=(10, 10))
plt.plot(y_hat_test, '#0000FF') # 예측값 blue
plt.plot(test_Seoul, '#FF0000') # 예측값 red

plt.legend(['Predicted', 'Actual'], loc='upper right', fontsize=10)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

plt.show()

# %%
# test의 Weihai를 array로 생성
test_Weihai = array(test["Weihai"])
x_test, y_test = split_sequence(test_Weihai, steps)

# %%
x_test = x_test.reshape((x_test.shape[0], x_test.shape[1], features))
y_hat_test = model.predict(x_test)

# %%
# 예측 모델 출력
plt.figure(figsize=(10, 10))
plt.plot(y_hat_test, '#0000FF') # 예측값 blue
plt.plot(test_Weihai, '#FF0000') # 예측값 red

plt.legend(['Predicted', 'Actual'], loc='upper right', fontsize=10)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

plt.show()
