# %%
from dateutil.parser import parse
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('raw_dataset_plus.csv', parse_dates=['Date'], index_col='Date')
df.head()
# Out:
#             Temperature  W_speed  W_direction  Humidity  Tianjin  Weihai  \
# Date
# 2014-01-01          4.0      3.7          270      51.3      136     116
# 2014-01-02          1.5      2.0          290      35.4      216      80
# 2014-01-03          2.3      2.5           50      54.4      102      67
# 2014-01-04         -0.1      2.4          270      47.1       74      30
# 2014-01-05         -0.8      1.9          270      48.4      114      77
#
#             Seoul
# Date
# 2014-01-01    125
# 2014-01-02     56
# 2014-01-03     59
# 2014-01-04     51
# 2014-01-05     45

# %%
def plot_df(df, x, y, title="", xlabel='Date', ylabel='Tianjin', dpi=100):
    plt.figure(figsize=(16,5), dpi=dpi)
    plt.plot(x, y, color='tab:red')
    plt.gca().set(title=title, xlabel=xlabel, ylabel=ylabel)
    plt.show()
    
plot_df(df, x=df.index, y=df.Tianjin, title='PM10 of Tianjin from 2014 to 2021.')

# %%
df.reset_index(inplace=True)

df['year'] = [d.year for d in df.Date]

# %%
fig, axes = plt.subplots(1,2, figsize=(20, 7), dpi=100)
sns.boxplot(x='year', y='Seoul', data=df, ax=axes[0])

axes[0].set_title('년도별 박스도표', fontsize=18)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-b4ae5249feb0> in <module>
# ----> 1 fig, axes = plt.subplot(1,2, figsize=(20, 7), dpi=100)
#       2 sns.boxplot(x=df.index, y=df.Seoul, data=df, ax=axes[0])
#       3
#       4 axes[0].set_title('년도별 박스도표', fontsize=18)
#       5
#
# c:\users\ad\appdata\local\programs\python\python38\lib\site-packages\matplotlib\pyplot.py in subplot(*args, **kwargs)
#    1241
#    1242     # First, search for an existing subplot with a matching spec.
# -> 1243     key = SubplotSpec._from_subplot_args(fig, args)
#    1244
#    1245     for ax in fig.axes:
#
# c:\users\ad\appdata\local\programs\python\python38\lib\site-packages\matplotlib\gridspec.py in _from_subplot_args(figure, args)
#     655                 i = j = num
#     656         else:
# --> 657             raise TypeError(f"subplot() takes 1 or 3 positional arguments but "
#     658                             f"{len(args)} were given")
#     659
#
# TypeError: subplot() takes 1 or 3 positional arguments but 2 were given
